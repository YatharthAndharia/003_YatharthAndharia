# %%
#Importing libraries
import numpy as np 
import pandas as pd 
import io
import matplotlib.pyplot as plt

# %%
# reading the csv file, del 2 columns from the file, checking first few rows of the file

data = pd.read_csv('BuyComputer.csv')

data.drop(columns=['User ID',],axis=1,inplace=True)
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
#Declare label as last column in the source file
#Y = data['Purchased'];
Y = data.iloc[:,-1].values

# %%
#Declaring X as all columns excluding last
#X = data.drop(columns=['Purchased',],axis=1,inplace=False)
X = data.iloc[:,:-1].values

# %%
# Splitting data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=3)

# %%
# Scaling data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Variabes to calculate sigmoid function
y_pred = []
total_features = len(X_train[0])
weight = []
bias = 0.2
print(total_features)
# Out:
# 2

# %%
total_entries = len(X_train[:,0])
total_entries
# Out:
# 300

# %%
for weights in range(total_features):
    weight.append(0)
weight
# Out:
# [0, 0]

# %%
# Sigmoid function
def sigmoid(n):

  return 1/(1 + np.exp(-n))

# %%
def predict(n):
    #w_t = np.array(weight).transpose(1, 0)
    return sigmoid(np.dot(weight,n)+bias)

# %%
#Loss function
def loss_func(y,a):
    J = -(y*np.log(a) + (1-y)*np.log(1-a))
    return J

# %%
dw = []
db = 0
J = 0
alpha = 0.1
for x in range(total_features):
    dw.append(0)

# %%
#Repeating the process 3000 times
for iterations in range(3000):
    for i in range(total_entries):
        localx = X_train[i]
        a = predict(localx)
        dz = a - y_train[i]
        J += loss_func(y_train[i],a)
        for j in range(total_features):
            dw[j] = dw[j]+(localx[j]*dz)
        db += dz
    J = J/total_entries
    db = db/total_entries
    for x in range(total_features):
        dw[x]=dw[x]/total_entries
    for x in range(total_features):
        weight[x] = weight[x]-(alpha*dw[x])
    bias = bias-(alpha*db)         
    J=0

# %%
#Print weight
print(weight)
# Out:
# [2.559118797457894, 1.2954443964186513]

# %%
#print bias
print(bias)
# Out:
# -1.1611633709751958

# %%
#predicting the label
for x in range(len(y_test)):
    y_pred.append(predict(X_test[x]))

# %%
#print actual and predicted values in a table
for x in range(len(y_pred)):
    #print('Actual ',y_test[x],' Predicted ',y_pred[x])
    if y_pred[x]>=0.5:
        y_pred[x]=1
    else:
        y_pred[x]=0

# %%
# Calculating accuracy of prediction
prediction_count = 0
for x in range(len(y_pred)):
    if(y_pred[x]==y_test[x]):
        prediction_count=prediction_count+1
print('Accuracy:',(prediction_count/(len(y_pred)))*100)
# Out:
# Accuracy: 83.0

# %% [markdown]
# #Using sklearn LogisticRegression model

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(random_state = 0)

#Fit
LR.fit(X_train, y_train)

#predicting the test label with LR. Predict always takes X as input
y_predLR=LR.predict(X_test)
#y_predLR
prediction_count = 0
for x in range(len(y_pred)):
    if(y_pred[x]==y_test[x]):
        prediction_count=prediction_count+1
print('Accuracy:',(prediction_count/(len(y_pred)))*100)
# Out:
# Accuracy: 83.0

# %% [markdown]
# **Exercise:**
#
# Try logistic regression on BuyComputer dataset and set Random state=Your_RollNumber (last 3 digit of ID, incase if you don't have ID)
