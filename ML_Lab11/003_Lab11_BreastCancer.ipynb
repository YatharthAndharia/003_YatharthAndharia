# %% [markdown]
# # Assignment: Perform SVM with PCA operation on Breast Cancer Dataset.

# %%
import pandas as pd
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn import svm,decomposition
import matplotlib.pyplot as plt
import numpy as np 
dataset = datasets.load_breast_cancer()
dataset.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset.data ,dataset.target, random_state=3)

print(X_train.shape, X_test.shape)
# Out:
# (426, 30) (143, 30)

# %%
pca = decomposition.PCA(n_components=20, whiten=True, random_state=3)
pca.fit(X_train)
# Out:
# PCA(n_components=20, random_state=3, whiten=True)

# %%
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)
print(X_train_pca.shape)

clf = svm.SVC(C=2., gamma=0.005, random_state=3)
clf.fit(X_train_pca, y_train)
# Out:
# (426, 20)
# SVC(C=2.0, gamma=0.005, random_state=3)

# %%
from sklearn import metrics
y_pred = clf.predict(X_test_pca)

print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93        53
#            1       0.94      0.99      0.96        90
#
#     accuracy                           0.95       143
#    macro avg       0.96      0.94      0.95       143
# weighted avg       0.95      0.95      0.95       143

# %%
from sklearn.pipeline import Pipeline
clf = Pipeline([('pca', decomposition.PCA(n_components=2, whiten=True)), ('svm', svm.LinearSVC(C=2.0))])

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
print(metrics.confusion_matrix(y_pred, y_test))
# Out:
# [[45  4]
#  [ 8 86]]
